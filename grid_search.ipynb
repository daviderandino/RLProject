# %% [markdown]
# # Grid Search UDR & ADR with PPO

# %% [markdown]
# ## Hopper

# %% [markdown]
# ### UDR

# %%
import importlib
import utils.UDRGridSearch

# Forza il ricaricamento del modulo modificato
importlib.reload(utils.UDRGridSearch)

from utils.UDRGridSearch import UDRGridSearch

# Hyper per la grid (indico direttamente i valori che voglio testare nella griglia)
UDR_RANGE_GRID = [0.3, 0.5, 0.7]
ARCHITECTURE_GRID = ["small", "medium", "large"]

# Hyper fissi (fuori grid)
LEARNING_RATE = 3e-4
LR_SCHEDULER_TYPE = "constant"
TIMESTEPS = 1_500_000
SEED = 928571

grid = UDRGridSearch(
    csv_name="hopper_udr_grid_search.csv",
    train_env_id="CustomHopper-source-v0",
    test_env_id="CustomHopper-target-v0",
    udr_range=UDR_RANGE_GRID,
    timesteps=TIMESTEPS,
    architecture=ARCHITECTURE_GRID,
    learning_rate=LEARNING_RATE,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    seed=SEED
)

grid.run_search()

# %% [markdown]
# ### ADR

# %%
import importlib
import utils.ADRGridSearch

# Forza il ricaricamento del modulo modificato
importlib.reload(utils.ADRGridSearch)

from utils.ADRGridSearch import ADRGridSearch

# Hyper per la grid (indico direttamente i valori che voglio testare nella griglia)
OBJ_ADR_GRID = [0.3, 0.5, 0.7]
REWARD_TH_GRID = [1200, 1500]
CHECK_FREQ_GRID = [40000, 80000]
ARCHITECTURE_GRID = ["small", "medium", "large"]

# Hyper fissi (fuori grid)
LEARNING_RATE = 3e-4
LR_SCHEDULER_TYPE = "constant"
STARTING_ADR_RANGE = 0.05
INCREASE_RATE = 0.05
TIMESTEPS = 1_500_000
SEED = 928571

grid = ADRGridSearch(
    csv_name="hopper_adr_grid_search.csv",
    train_env_id="CustomHopper-source-v0",
    test_env_id="CustomHopper-target-v0",
    obj_adr_range=OBJ_ADR_GRID,
    reward_threshold=REWARD_TH_GRID,
    check_freq=CHECK_FREQ_GRID,
    timesteps=TIMESTEPS,
    architecture=ARCHITECTURE_GRID,
    increase_rate=INCREASE_RATE,
    learning_rate=LEARNING_RATE,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    starting_adr_range=STARTING_ADR_RANGE,
    seed=SEED
)

grid.run_search()

# %% [markdown]
# ## Walker2D

# %% [markdown]
# ### UDR

# %%
import importlib
import utils.UDRGridSearch

# Forza il ricaricamento del modulo modificato
importlib.reload(utils.UDRGridSearch)

from utils.UDRGridSearch import UDRGridSearch

# Hyper per la grid (indico direttamente i valori che voglio testare nella griglia)
UDR_RANGE_GRID = [0.3, 0.5, 0.7]
ARCHITECTURE_GRID = ["small", "medium", "large"]

# Hyper fissi (fuori grid)
LEARNING_RATE = 3e-4
LR_SCHEDULER_TYPE = "constant"
TIMESTEPS = 1_500_000
SEED = 928571

grid = UDRGridSearch(
    csv_name="walker_udr_grid_search.csv",
    train_env_id="CustomWalker-source-v0",
    test_env_id="CustomWalker-target-v0",
    udr_range=UDR_RANGE_GRID,
    timesteps=TIMESTEPS,
    architecture=ARCHITECTURE_GRID,
    learning_rate=LEARNING_RATE,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    seed=SEED
)

grid.run_search()

# %% [markdown]
# ### ADR

# %%
import importlib
import utils.ADRGridSearch

# Forza il ricaricamento del modulo modificato
importlib.reload(utils.ADRGridSearch)

from utils.ADRGridSearch import ADRGridSearch

# Hyper per la grid (indico direttamente i valori che voglio testare nella griglia)
OBJ_ADR_GRID = [0.3, 0.5, 0.7]
REWARD_TH_GRID = [1700, 2000]
CHECK_FREQ_GRID = [40000, 80000]
ARCHITECTURE_GRID = ["small", "medium", "large"]

# Hyper fissi (fuori grid)
LEARNING_RATE = 3e-4
LR_SCHEDULER_TYPE = "constant"
STARTING_ADR_RANGE = 0.05
INCREASE_RATE = 0.05
TIMESTEPS = 1_500_000
SEED = 928571

grid = ADRGridSearch(
    csv_name="walker_adr_grid_search.csv",
    train_env_id="CustomWalker-source-v0",
    test_env_id="CustomWalker-target-v0",
    obj_adr_range=OBJ_ADR_GRID,
    reward_threshold=REWARD_TH_GRID,
    check_freq=CHECK_FREQ_GRID,
    timesteps=TIMESTEPS,
    architecture=ARCHITECTURE_GRID,
    increase_rate=INCREASE_RATE,
    learning_rate=LEARNING_RATE,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    starting_adr_range=STARTING_ADR_RANGE,
    seed=SEED
)

grid.run_search()
